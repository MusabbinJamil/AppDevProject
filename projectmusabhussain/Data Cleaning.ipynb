# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder # for reverse encoding
import datetime as dt
from datetime import datetime, timedelta

# %%
df = pd.read_csv(r"E:\IBA\Semester 0\Application Development\Project\Python Code\Original Data.csv")

# %%
df.head()
# Out:
#                                                  url  timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...      731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...      731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...      731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...      731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/      731.0
#
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  ...  \
# 0                  0.815385        4.0             2.0       1.0  ...
# ...

# %%
df.columns
# Out:
# Index(['url', 'timedelta', 'n_tokens_title', 'n_tokens_content',
#        'n_unique_tokens', 'n_non_stop_words', 'n_non_stop_unique_tokens',
#        'num_hrefs', 'num_self_hrefs', 'num_imgs', 'num_videos',
#        'average_token_length', 'num_keywords', 'data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', 'data_channel_is_bus',
#        'data_channel_is_socmed', 'data_channel_is_tech',
#        'data_channel_is_world', 'kw_min_min', 'kw_max_min', 'kw_avg_min',
#        'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 'kw_max_avg',
#        'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares',
#        'self_reference_avg_sharess', 'weekday_is_monday', 'weekday_is_tuesday',
#        'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday',
#        'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00',
#        'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity',
# ...

# %%
monday_data = df['weekday_is_monday'].replace(1,'Monday')
monday_data
# Out:
# 0        Monday
# 1        Monday
# 2        Monday
# 3        Monday
# 4        Monday
#           ...
# 39639       0.0
# 39640       0.0
# 39641       0.0
# 39642       0.0
# 39643       0.0
# Name: weekday_is_monday, Length: 39644, dtype: object

# %%
# does not work
for column in ('weekday_is%'):
    column+'_data' = df['weekday_'+column].replace(1,column)
# Out:
#   Cell In[115], line 3
#     column+'_data' = df['weekday_'+column].replace(1,column)
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
day_data = df[['weekday_is_monday', 'weekday_is_tuesday',
       'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday',
       'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend']]
day_data

# %%
day_data2 = day_data.idxmax(1)

# %%
day_data3 = day_data2.str.replace('weekday_is_','')

# %%
day_data4 = day_data3.str.replace('is_','')

# %%
day_data4
# Out:
# 0           monday
# 1           monday
# 2           monday
# 3           monday
# 4           monday
#            ...
# 39639    wednesday
# 39640    wednesday
# 39641    wednesday
# 39642    wednesday
# 39643    wednesday
# Length: 39644, dtype: object

# %%
# final_project_data = day_data4.copy()   # will be copied later

# %%
final_project_data
# Out:
#                                                     link           genre  \
# 0      http://mashable.com/2013/01/07/amazon-instant-...   entertainment
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...        business
# 2      http://mashable.com/2013/01/07/apple-40-billio...        business
# 3      http://mashable.com/2013/01/07/astronaut-notre...   entertainment
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/      technology
# ...                                                  ...             ...
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...      technology
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...    social media
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...       lifestyle
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/           world
# 39643  http://mashable.com/2014/12/27/youtube-channel...   entertainment
#
#             date  shares  title_word_count  content_word_count  \
# ...

# %%
channel_data = df[['data_channel_is_lifestyle',
       ' data_channel_is_entertainment', 'data_channel_is_bus',
       'data_channel_is_socmed', 'data_channel_is_tech',
       'data_channel_is_world']]

# %%
channel_data2 = channel_data.idxmax(1)

# %%
channel_data3 = channel_data2.str.replace('data_channel_is_','')

# %%
channel_data4 = channel_data3.str.replace('bus','business')
channel_data5 = channel_data4.str.replace('socmed','social media')
channel_data6 = channel_data5.str.replace('tech','technology')

# %%
channel_data6
# Out:
# 0         entertainment
# 1              business
# 2              business
# 3         entertainment
# 4            technology
#               ...
# 39639        technology
# 39640      social media
# 39641         lifestyle
# 39642             world
# 39643     entertainment
# Length: 39644, dtype: object

# %%
#final_project_data  = final_project_data+channel_data6                dont run not joining correctly

# %%
#del final_project_data                                                #error rectified

# %%
final_project_data = []
final_project_data = pd.DataFrame(final_project_data)

# %%
final_project_data['channel_data'] = channel_data6.copy()

# %%
final_project_data['day_data'] = day_data4.copy()

# %%
final_project_data['shares'] = df['shares'].copy()

# %%
final_project_data['title_word_count'] = df['n_tokens_title'].copy()

# %%
final_project_data['content_word_count'] = df['n_tokens_content'].copy()

# %%
final_project_data.insert(1,'link',df['url'])

# %%
final_project_data['link'],final_project_data['channel_data'] = final_project_data['channel_data'],final_project_data['link']

# %%
final_project_data.rename(columns = {'channel_data':'link','link':'channel_data'}, inplace = True)

# %%
final_project_data.rename(columns = {'channel_data':'genre'}, inplace = True)

# %%
# final_project_data['']

# %%
final_project_data.head()
# Out:
#                                                 link           genre day_data  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...   entertainment   monday
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...        business   monday
# 2  http://mashable.com/2013/01/07/apple-40-billio...        business   monday
# 3  http://mashable.com/2013/01/07/astronaut-notre...   entertainment   monday
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/      technology   monday
#
#    shares  title_word_count  content_word_count
# 0     593              12.0               219.0
# 1     711               9.0               255.0
# 2    1500               9.0               211.0
# 3    1200               9.0               531.0
# 4     505              13.0              1072.0

# %%
df['n_tokens_title']
# Out:
# 0        12.0
# 1         9.0
# 2         9.0
# 3         9.0
# 4        13.0
#          ...
# 39639    11.0
# 39640    12.0
# 39641    10.0
# 39642     6.0
# 39643    10.0
# Name: n_tokens_title, Length: 39644, dtype: float64

# %%
df.iloc[39640]
# Out:
# url                             http://mashable.com/2014/12/27/seth-rogen-jame...
# timedelta                                                                     8.0
# n_tokens_title                                                               12.0
# n_tokens_content                                                            328.0
# n_unique_tokens                                                          0.696296
#                                                       ...
# title_subjectivity                                                            0.3
# title_sentiment_polarity                                                      1.0
# abs_title_subjectivity                                                        0.2
# abs_title_sentiment_polarity                                                  1.0
# shares                                                                       1900
# Name: 39640, Length: 61, dtype: object

# %%
# more columns we can add
# num_hrefs:               Number of links 
# num_self_hrefs:          Number of links to other articles published by Mashable 
# num_imgs:                Number of images 
# num_videos:              Number of videos
# rate_positive_words:     Rate of positive words among non-neutral tokens 
# rate_negative_words:     Rate of negative words among non-neutral tokens

# %%
# adding these : avg_positive_polarity	avg_negative_polarity	title_sentiment_polarity

# %%
final_project_data['avg_positive_polarity'] = df['avg_positive_polarity'].copy()

# %%
final_project_data['avg_negative_polarity'] = df['avg_negative_polarity'].copy()

# %%
final_project_data['title_sentiment_polarity'] = df['title_sentiment_polarity'].copy()

# %%
timestamp = dt.datetime.fromtimestamp(1571702400-731)
print(timestamp.strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2019-10-22 04:47:49

# %%
delta = timedelta(days=731)

start_date = datetime(2015, 1, 8)
new_date = start_date - delta

# %%
print("Starting Date:", start_date)
print("Time Delta:", delta)
print("New Date:", new_date)
# Out:
# Starting Date: 2015-01-08 00:00:00
# Time Delta: 731 days, 0:00:00
# New Date: 2013-01-07 00:00:00

# %%
final_project_data
# Out:
#                                                     link           genre  \
# 0      http://mashable.com/2013/01/07/amazon-instant-...   entertainment
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...        business
# 2      http://mashable.com/2013/01/07/apple-40-billio...        business
# 3      http://mashable.com/2013/01/07/astronaut-notre...   entertainment
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/      technology
# ...                                                  ...             ...
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...      technology
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...    social media
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...       lifestyle
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/           world
# 39643  http://mashable.com/2014/12/27/youtube-channel...   entertainment
#
#         day_data  shares  title_word_count  content_word_count  \
# ...

# %%
#final_project_data = pd.read_csv('Final Project Data.csv')
final_project_data.insert(2,'date',df['timedelta'])

# %%
# final_project_data = final_project_data.drop(columns='Unnamed: 0')

# %%
final_project_data
# Out:
#                                                     link           genre  \
# 0      http://mashable.com/2013/01/07/amazon-instant-...   entertainment
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...        business
# 2      http://mashable.com/2013/01/07/apple-40-billio...        business
# 3      http://mashable.com/2013/01/07/astronaut-notre...   entertainment
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/      technology
# ...                                                  ...             ...
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...      technology
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...    social media
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...       lifestyle
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/           world
# 39643  http://mashable.com/2014/12/27/youtube-channel...   entertainment
#
#         date   day_data  shares  title_word_count  content_word_count  \
# ...

# %%
df = final_project_data['date']

# Function to convert '731.0' to timedelta and then calculate the new date
def convert_to_date(value):
    days = int(float(value))  # Convert '731.0' to integer
    delta = timedelta(days=days)
    start_date = datetime(2015, 1, 8)  # Starting date
    new_date = start_date - delta
    return new_date

# Apply the function to the DataFrame column
df = df.apply(convert_to_date)

# %%
print(df)
# Out:
# 0       2013-01-07
# 1       2013-01-07
# 2       2013-01-07
# 3       2013-01-07
# 4       2013-01-07
#            ...
# 39639   2014-12-31
# 39640   2014-12-31
# 39641   2014-12-31
# 39642   2014-12-31
# 39643   2014-12-31
# Name: date, Length: 39644, dtype: datetime64[ns]

# %%
final_project_data['date'] = df

# %%
final_project_data
# Out:
#                                                     link           genre  \
# 0      http://mashable.com/2013/01/07/amazon-instant-...   entertainment
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...        business
# 2      http://mashable.com/2013/01/07/apple-40-billio...        business
# 3      http://mashable.com/2013/01/07/astronaut-notre...   entertainment
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/      technology
# ...                                                  ...             ...
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...      technology
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...    social media
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...       lifestyle
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/           world
# 39643  http://mashable.com/2014/12/27/youtube-channel...   entertainment
#
#             date   day_data  shares  title_word_count  content_word_count  \
# ...

# %%
final_project_data.to_csv('Final Project Data.csv')
